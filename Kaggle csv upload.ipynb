# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-79b62abf-d53c-4886-be29-c92d0887d8d3" name="files[]" multiple disabled />
#      <output id="result-79b62abf-d53c-4886-be29-c92d0887d8d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cal_test.csv to cal_test.csv

# %% [markdown]
# Let's see what this file looks like.

# %%
print (uploaded['cal_test.csv'][:200].decode('utf-8') + '...')
# Out:
# listing_id,date,available,price
# 241032,1/4/16,t,$85.00
# 241032,1/5/16,t,$85.00
# 241032,1/6/16,f,
# 241032,1/7/16,f,
# 241032,1/8/16,f,
# 241032,1/9/16,f,
# 241032,1/10/16,f,
# 241032,1/11/16,f,
# 241032,...

# %% [markdown]
# First row is rolumn labels, followed by a CSV. `read_csv` should work. Let's see.

# %%
import pandas as pd
import io

df = pd.read_csv(io.StringIO(uploaded['cal_test.csv'].decode('utf-8')))
df
# Out:
#     listing_id     date available    price
# 0       241032   1/4/16         t  $85.00
# 1       241032   1/5/16         t  $85.00
# 2       241032   1/6/16         f      NaN
# 3       241032   1/7/16         f      NaN
# 4       241032   1/8/16         f      NaN
# 5       241032   1/9/16         f      NaN
# 6       241032  1/10/16         f      NaN
# 7       241032  1/11/16         f      NaN
# 8       241032  1/12/16         f      NaN
# 9       241032  1/13/16         t  $85.00
# 10      241032  1/14/16         t  $85.00
# 11      241032  1/15/16         f      NaN
# 12      241032  1/16/16         f      NaN
# 13      241032  1/17/16         f      NaN
# 14      241032  1/18/16         t  $85.00
# 15      241032  1/19/16         t  $85.00
# 16      241032  1/20/16         t  $85.00
# 17      241032  1/21/16         f      NaN
# 18      241032  1/22/16         f      NaN
# 19      241032  1/23/16         f      NaN
# 20      241032  1/24/16         t  $85.00
# 21      241032  1/25/16         t  $85.00
# 22      241032  1/26/16         t  $85.00
# 23      241032  1/27/16         t  $85.00
# 24      241032  1/28/16         t  $85.00
