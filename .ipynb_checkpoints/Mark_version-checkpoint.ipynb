# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor

Seattle_file_path = '/Users/I/Downloads/Seattle/listings.csv'
Seattle_data = pd.read_csv(Seattle_file_path)
Seattle_data.describe()
Seattle_data.columns
features = ['beds','accommodates','latitude','longitude','bathrooms','bedrooms','price','host_listings_count','reviews_per_month','review_scores_rating']

# %%
Data = Seattle_data[features]
Data.dropna()
# Out:
#       host_response_rate  beds  accommodates   latitude   longitude  \
# 0                   0.96   1.0             4  47.636289 -122.371025
# 1                   0.98   1.0             4  47.639123 -122.365667
# 2                   0.67   7.0            11  47.629724 -122.369483
# 4                   1.00   3.0             6  47.632918 -122.372471
# 6                   1.00   1.0             2  47.636605 -122.368519
# 7                   1.00   1.0             2  47.640161 -122.375856
# 9                   0.98   1.0             4  47.637492 -122.366889
# 10                  1.00   1.0             2  47.635482 -122.358478
# 11                  1.00   1.0             2  47.637214 -122.360046
# 12                  1.00   3.0             4  47.635546 -122.373171
# 13                  1.00   3.0             5  47.629507 -122.367629
# 14                  1.00  15.0            16  47.639203 -122.365863
# 15                  1.00   2.0             5  47.635650 -122.372893
# 16                  1.00   1.0             2  47.626200 -122.366602
# 17                  1.00   1.0             2  47.640646 -122.372406
# 20                  1.00   1.0             1  47.627940 -122.364959
# 21                  1.00   2.0             3  47.636374 -122.361033
# 22                  1.00   4.0             8  47.635632 -122.358881
# 25                  0.67   5.0             8  47.631397 -122.367767
# 27                  1.00   1.0             2  47.639266 -122.374726
# 28                  1.00   3.0             6  47.629907 -122.368948
# 29                  0.71   2.0             3  47.639816 -122.374339
# 30                  0.98   1.0             4  47.639008 -122.365320
# 31                  0.97   3.0             6  47.635085 -122.364444
# 32                  0.60   2.0             4  47.640633 -122.372709
# 33                  0.71   3.0             7  47.638121 -122.375790
# 34                  1.00   2.0             4  47.629816 -122.366212
# 35                  1.00   2.0             4  47.639810 -122.373801
# 36                  0.50   3.0             8  47.635570 -122.361653
# 37                  0.31   1.0             1  47.634979 -122.358869
# ...                  ...   ...           ...        ...         ...
# 3782                1.00   2.0             3  47.660884 -122.354345
# 3783                1.00   1.0             2  47.655846 -122.356491
# 3784                1.00   1.0             2  47.660342 -122.364747
# 3785                1.00   1.0             3  47.653176 -122.346211
# 3786                0.97   1.0             1  47.661396 -122.352256
# 3787                1.00   4.0             6  47.658552 -122.348265
# 3788                1.00   2.0             4  47.656739 -122.344865
# 3789                1.00   1.0             2  47.661171 -122.349923
# 3790                1.00   3.0             6  47.649271 -122.347817
# 3791                1.00   1.0             2  47.659149 -122.363466
# 3793                1.00   2.0             4  47.660056 -122.357683
# 3794                0.80   1.0             2  47.654199 -122.359987
# 3795                1.00   1.0             4  47.650124 -122.343283
# 3796                1.00   1.0             2  47.656508 -122.360571
# 3797                1.00   1.0             2  47.658976 -122.354915
# 3798                1.00   1.0             2  47.655381 -122.343205
# 3799                0.25   1.0             2  47.652902 -122.352110
# 3801                1.00   1.0             2  47.657078 -122.358795
# 3803                0.97  10.0            16  47.661131 -122.349238
# 3804                1.00   1.0             2  47.660856 -122.352401
# 3805                1.00   2.0             6  47.653158 -122.356285
# 3806                1.00   2.0             4  47.656057 -122.354513
# 3807                1.00   1.0             2  47.654304 -122.342720
# 3808                1.00   3.0             6  47.662036 -122.350485
# 3809                1.00   1.0             4  47.648689 -122.343915
# 3810                1.00   3.0             5  47.654205 -122.352604
# 3811                1.00   1.0             3  47.657898 -122.346692
# 3812                1.00   2.0             4  47.654516 -122.358124
# 3813                0.99   3.0             6  47.664295 -122.359170
# 3814                1.00   2.0             4  47.649552 -122.318309
#
#       bathrooms  bedrooms  price  host_listings_count  reviews_per_month  \
# 0           1.0       1.0     85                  3.0               4.07
# 1           1.0       1.0    150                  6.0               1.48
# 2           4.5       5.0    975                  2.0               1.15
# 4           2.0       3.0    450                  2.0               0.89
# 6           1.0       1.0     80                  1.0               2.46
# 7           1.0       1.0     60                  5.0               4.73
# 9           1.0       1.0    150                  6.0               1.55
# 10          1.0       1.0     95                  1.0               3.33
# 11          1.0       1.0     99                  1.0               0.98
# 12          1.0       2.0    245                  1.0               0.92
# 13          1.0       2.0    165                  1.0               3.00
# 14          3.5       6.0    461                  1.0               2.65
# 15          1.0       2.0    109                  1.0               0.73
# 16          1.0       1.0     66                  1.0               4.55
# 17          1.0       1.0     99                  1.0               4.58
# 20          1.0       1.0    110                  1.0               1.00
# 21          1.5       1.0     99                  1.0               0.71
# 22          2.0       4.0    450                  1.0               0.86
# 25          2.5       3.0    450                  2.0               1.30
# 27          1.0       1.0     45                  5.0               4.38
# 28          2.0       3.0    300                  5.0               2.47
# 29          1.0       1.0     80                  1.0               0.33
# 30          1.0       1.0    175                  6.0               1.86
# 31          1.5       3.0    325                  9.0               2.18
# 32          3.0       3.0    175                  1.0               1.31
# 33          3.5       4.0    222                  1.0               0.99
# 34          1.0       2.0    159                  1.0               2.27
# 35          1.0       1.0    125                  2.0               4.35
# 36          3.0       3.0    348                  1.0               0.97
# 37          1.0       1.0     45                  1.0               0.90
# ...         ...       ...    ...                  ...                ...
# 3782        1.0       1.0     99                  1.0               2.61
# 3783        1.0       1.0     90                  1.0               1.71
# 3784        1.0       1.0    110                  2.0               1.25
# 3785        1.0       1.0     80                  1.0               0.66
# 3786        1.5       1.0     87                  7.0               0.44
# 3787        2.5       3.0    260                  3.0               0.41
# 3788        1.0       1.0    115                  1.0               3.39
# 3789        1.0       1.0     60                  2.0               2.14
# 3790        1.0       2.0    175                  1.0               3.77
# 3791        1.0       1.0     85                  1.0               2.48
# 3793        1.0       0.0    109                  1.0               4.28
# 3794        1.0       1.0    107                  1.0               3.10
# 3795        1.0       0.0    200                  1.0               1.18
# 3796        1.0       1.0     85                  1.0               5.57
# 3797        1.0       0.0     70                  1.0               1.00
# 3798        1.0       1.0     77                  2.0               5.95
# 3799        1.0       1.0     65                  1.0               1.06
# 3801        1.0       1.0    108                  1.0               2.05
# 3803        3.5       4.0    250                  9.0               4.00
# 3804        1.0       0.0    125                  1.0               2.34
# 3805        1.0       2.0    100                  1.0               3.95
# 3806        1.0       2.0    160                  2.0               0.24
# 3807        1.0       0.0    109                  1.0               0.78
# 3808        2.0       3.0    175                  2.0               1.15
# 3809        1.0       1.0    120                  1.0               1.18
# 3810        1.0       2.0    154                  1.0               1.56
# 3811        1.0       1.0     65                  1.0               0.63
# 3812        1.0       1.0     95                  3.0               4.01
# 3813        2.0       3.0    359                354.0               0.30
# 3814        1.0       1.0     79                  1.0               2.00
#
#       review_scores_rating
# 0                     95.0
# 1                     96.0
# 2                     97.0
# 4                     92.0
# 6                     99.0
# 7                     97.0
# 9                     97.0
# 10                    97.0
# 11                    97.0
# 12                    98.0
# 13                   100.0
# 14                    98.0
# 15                    80.0
# 16                    95.0
# 17                    98.0
# 20                   100.0
# 21                    84.0
# 22                   100.0
# 25                   100.0
# 27                    95.0
# 28                   100.0
# 29                    85.0
# 30                    96.0
# 31                    92.0
# 32                    88.0
# 33                    75.0
# 34                    97.0
# 35                    95.0
# 36                    96.0
# 37                    97.0
# ...                    ...
# 3782                  97.0
# 3783                  88.0
# 3784                  95.0
# 3785                  96.0
# 3786                  98.0
# 3787                  98.0
# 3788                  99.0
# 3789                  90.0
# 3790                  98.0
# 3791                 100.0
# 3793                  98.0
# 3794                  90.0
# 3795                  98.0
# 3796                  98.0
# 3797                 100.0
# 3798                  98.0
# 3799                  95.0
# 3801                 100.0
# 3803                  95.0
# 3804                  95.0
# 3805                  98.0
# 3806                 100.0
# 3807                  97.0
# 3808                  96.0
# 3809                  80.0
# 3810                  92.0
# 3811                 100.0
# 3812                  96.0
# 3813                  80.0
# 3814                 100.0
#
# [2841 rows x 11 columns]

# %%
y = Droped_data.review_scores_rating * Droped_data.reviews_per_month
Selected_features = ['host_response_rate','beds','accommodates','latitude','longitude','bathrooms','bedrooms','price','host_listings_count']
X = Droped_data[Selected_features]

# %%
print(Droped_data.describe())
# Out:
#        host_response_rate         beds  accommodates     latitude  \
# count         2841.000000  2841.000000   2841.000000  2841.000000
# mean             0.952432     1.748680      3.395635    47.628409
# std              0.112542     1.158033      1.999587     0.042793
# min              0.170000     1.000000      1.000000    47.507284
# 25%              0.990000     1.000000      2.000000    47.608419
# 50%              1.000000     1.000000      3.000000    47.623025
# 75%              1.000000     2.000000      4.000000    47.662361
# max              1.000000    15.000000     16.000000    47.733358
#
#          longitude    bathrooms     bedrooms        price  \
# count  2841.000000  2841.000000  2841.000000  2841.000000
# mean   -122.332945     1.256248     1.286519   123.710313
# std       0.031700     0.593970     0.862108    87.202263
# min    -122.417219     0.000000     0.000000    22.000000
# 25%    -122.353415     1.000000     1.000000    72.000000
# 50%    -122.329389     1.000000     1.000000   100.000000
# 75%    -122.310463     1.000000     2.000000   149.000000
# max    -122.254189     8.000000     7.000000   999.000000
#
#        host_listings_count  reviews_per_month  review_scores_rating
# count          2841.000000        2841.000000           2841.000000
# mean              7.471313           2.233640             94.546639
# std              26.695426           1.848636              6.524819
# min               1.000000           0.030000             20.000000
# 25%               1.000000           0.820000             93.000000
# 50%               1.000000           1.740000             96.000000
# 75%               3.000000           3.160000             99.000000
# max             502.000000          12.150000            100.000000

# %%
y.describe()
# Out:
# count    2841.000000
# mean      212.351155
# std       177.010508
# min         2.700000
# 25%        77.000000
# 50%       165.620000
# 75%       303.030000
# max      1154.250000
# dtype: float64

# %%
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state = 0)
Seattle_model = RandomForestRegressor()
Seattle_model.fit(train_X, train_y)
# Out:
# /Users/I/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
val_predictions = Seattle_model.predict(val_X)
print(mean_absolute_error(val_y, val_predictions))
# Out:
# 122.40346554149086

# %%
print(Seattle_model.predict(val_X.head()))
# Out:
# [146.29  213.201 218.336 111.326 165.953]

# %%
val_y.head()
# Out:
# 1411    193.50
# 2665     89.00
# 406     246.72
# 2700    115.90
# 3509    100.00
# dtype: float64

# %%
def get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y):
    model = RandomForestRegressor(max_leaf_nodes=max_leaf_nodes, random_state=0)
    model.fit(train_X, train_y)
    preds_val = model.predict(val_X)
    mae = mean_absolute_error(val_y, preds_val)
    return(mae)

# %%
for max_leaf_nodes in [10, 100, 200,3000]:
    my_mae = get_mae(max_leaf_nodes, train_X, val_X, train_y, val_y)
    print("Max leaf nodes: %d  \t\t Mean Absolute Error:  %d" %(max_leaf_nodes, my_mae))
# Out:
# /Users/I/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/I/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /Users/I/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# Max leaf nodes: 10  		 Mean Absolute Error:  122
# Max leaf nodes: 100  		 Mean Absolute Error:  121
# Max leaf nodes: 200  		 Mean Absolute Error:  122
# Max leaf nodes: 3000  		 Mean Absolute Error:  126
# /Users/I/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
